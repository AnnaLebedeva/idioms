# %% [markdown]
# В этой тетрадке описывается алгоритм решения задачи извлечения из Wiktionary списка идиом немецкого языка, а также, при наличии информации, сопоставления каждой идиоме её части речи, буквального значения, фигурального значения, а также присвоение ссылки на страницу этой идиомы в Wiktionary.

# %% [markdown]
# Для их извлечения информации с Wiktionary будем пользоваться пакетом WiktionaryParser (https://pypi.org/project/wiktionaryparser/).

# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import json
import re
import csv
import pandas as pd
from collections import Counter
from tqdm import tqdm

from wiktionaryparser import WiktionaryParser
parser = WiktionaryParser()

# %% [markdown]
# Для начала создаем словарь идиома - ссылка на её страницу в Wiktionary:

# %%
url = 'https://en.wiktionary.org/wiki/Category:German_idioms'
dict_of_links = {}
while True:
    page = requests.get(url)
    html = page.text
    soup = BeautifulSoup(html)
    for item in soup.select("div[class='mw-category-generated'] a[href^='/wiki/']"):
        if re.search('(?<=>)(.*)(?=<)', str(item)).group(0) == 'Synonymes de langues en français':
            pass
        else:
            collocation = re.search('(?<=>)(.*)(?=<)', str(item)).group(0)
            link = 'https://en.wiktionary.org'+re.search('(?<=href=")([^"]*)', str(item)).group(0)
            dict_of_links[collocation] = link
        #     print('https://en.wiktionary.org'+re.search('(?<=href=")([^"]*)', str(item)).group(0))
    next_page_available = 0
    for i in soup.find_all('a'):
        if i.string == 'next page':
            url='https://en.wiktionary.org/'+i['href']
            next_page_available = 1
            break
    if not next_page_available:
        break
# dict_of_links

# %% [markdown]
# При парсинге попала одна лишняя ссылка, удалим её:

# %%
del dict_of_links['German rhetorical questions']

# %%
len(dict_of_links)
# Out:
# 801

# %% [markdown]
# У многих идиом на странице нет их определения, а есть ссылка на альтернативную форму или иное написание. Нам нужно углубляться по ссылке до тех пор, пока мы не попадем на определение. Сделаем функцию для извлечения финального определения:

# %%
def final_definition(collocation):
    check = 1
    while check == True:
        collocation_info = parser.fetch(collocation, 'german')
        if collocation_info!=[]:
            if collocation_info[0]['definitions']!=[]:
                for definition in collocation_info[0]['definitions'][0]['text'][1:]:
                    if "alternative form of " in definition.lower():
                        collocation = re.search('(?<=[Aa]lternative form of )(.*)', definition).group(0)
                    elif "alternative spelling of " in definition.lower():
                        collocation = re.search('(?<=[Aa]lternative spelling of )(.*)', definition).group(0)
                    elif "synonym of " in definition.lower():
                        collocation = re.search('(?<=[Ss]ynonym of )(.*)', definition).group(0)
                    else:
                        check = 0
    collocation_info = parser.fetch(collocation, 'german')
    if collocation_info!=[]:
        if collocation_info[0]['definitions']!=[]:
            return collocation_info[0]['definitions'][0]['text'][1:]
        else:
            return ' '

# %% [markdown]
# Достаём определения и помещаем в список:
# 1. часть речи, соответствующую идиоме
# 2. строку, содержащую все определения через точку с запятой
# 3. ссылку на страницу идиомы
# 4. буквальное значение
#
# Этот список добавляем в список списков.

# %%
from tqdm import tqdm

list_for_file = []
for collocation in tqdm(dict_of_links):
    try:
        collocation_info = parser.fetch(collocation, 'german')
        if collocation_info!=[]:
            if collocation_info[0]['definitions']!=[]:
#                 добавляем идиому:
                list_for_collocation = [collocation]
#     добавляем часть речи, если есть:
                if 'partOfSpeech' in collocation_info[0]['definitions'][0]:
                    list_for_collocation.append(collocation_info[0]['definitions'][0]['partOfSpeech'])
                else:
                    list_for_collocation.append('')
#         добавляем определения, предварительно углубившись до нужной страницы
                list_for_collocation.append("; ".join(final_definition(collocation)))
#     добавляем ссылку на страницу идиомы:
                list_for_collocation.append(dict_of_links[collocation])
#                 добавляем literal meaning, если оно есть
                if collocation_info[0]['etymology']!=[]:
                    if not re.search('(?<=Literally, ")([^"]*)', collocation_info[0]['etymology']):
                        list_for_collocation.append('')
                    else:
                        list_for_collocation.append(re.search('(?<=Literally, ")([^"]*)', \
                                                              collocation_info[0]['etymology']).group(0))
                else:
                    list_for_collocation.append('')
                list_for_file.append(list_for_collocation)
    except AttributeError:
        pass
# list_for_file

# %%
len(list_for_file)
# Out:
# 769

# %% [markdown]
# Получилось достать определения для 769 идиом. Запишем информацию в файл.

# %%
with open('German_idioms_1601.tsv', 'w', newline='') as record_file:
    tsv_writer = csv.writer(record_file, delimiter='\t', lineterminator='\n')
    tsv_writer.writerow(['Collocation', 'Part_of_speech', 'Literal meaning', 'Definition', 'Link'])
    for collocation_info in list_for_file:
        tsv_writer.writerow([collocation_info[0], collocation_info[1], collocation_info[4],\
collocation_info[2], dict_of_links[collocation_info[0]]])

# %% [markdown]
# Посмотрим, что получилось.

# %%
df = pd.read_csv('German_idioms_1601.tsv', delimiter='\t')
def left_align(df):
    left_aligned_df = df.style.set_properties(**{'text-align': 'left'})
    left_aligned_df = left_aligned_df.set_table_styles(
        [dict(selector='th', props=[('text-align', 'left')])]
    )
    return left_aligned_df
pd.options.display.max_colwidth=100
pd.options.display.max_rows=50
# display(left_align(df[['Collocation','Part_of_speech','Definition']].head(500)))
display(left_align(df))
# Out:
# <style type="text/css">
# #T_d0cfa th {
#   text-align: left;
# }
# #T_d0cfa_row0_col0, #T_d0cfa_row0_col1, #T_d0cfa_row0_col2, #T_d0cfa_row0_col3, #T_d0cfa_row0_col4, #T_d0cfa_row1_col0, #T_d0cfa_row1_col1, #T_d0cfa_row1_col2, #T_d0cfa_row1_col3, #T_d0cfa_row1_col4, #T_d0cfa_row2_col0, #T_d0cfa_row2_col1, #T_d0cfa_row2_col2, #T_d0cfa_row2_col3, #T_d0cfa_row2_col4, #T_d0cfa_row3_col0, #T_d0cfa_row3_col1, #T_d0cfa_row3_col2, #T_d0cfa_row3_col3, #T_d0cfa_row3_col4, #T_d0cfa_row4_col0, #T_d0cfa_row4_col1, #T_d0cfa_row4_col2, #T_d0cfa_row4_col3, #T_d0cfa_row4_col4, #T_d0cfa_row5_col0, #T_d0cfa_row5_col1, #T_d0cfa_row5_col2, #T_d0cfa_row5_col3, #T_d0cfa_row5_col4, #T_d0cfa_row6_col0, #T_d0cfa_row6_col1, #T_d0cfa_row6_col2, #T_d0cfa_row6_col3, #T_d0cfa_row6_col4, #T_d0cfa_row7_col0, #T_d0cfa_row7_col1, #T_d0cfa_row7_col2, #T_d0cfa_row7_col3, #T_d0cfa_row7_col4, #T_d0cfa_row8_col0, #T_d0cfa_row8_col1, #T_d0cfa_row8_col2, #T_d0cfa_row8_col3, #T_d0cfa_row8_col4, #T_d0cfa_row9_col0, #T_d0cfa_row9_col1, #T_d0cfa_row9_col2, #T_d0cfa_row9_col3, #T_d0cfa_row9_col4, #T_d0cfa_row10_col0, #T_d0cfa_row10_col1, #T_d0cfa_row10_col2, #T_d0cfa_row10_col3, #T_d0cfa_row10_col4, #T_d0cfa_row11_col0, #T_d0cfa_row11_col1, #T_d0cfa_row11_col2, #T_d0cfa_row11_col3, #T_d0cfa_row11_col4, #T_d0cfa_row12_col0, #T_d0cfa_row12_col1, #T_d0cfa_row12_col2, #T_d0cfa_row12_col3, #T_d0cfa_row12_col4, #T_d0cfa_row13_col0, #T_d0cfa_row13_col1, #T_d0cfa_row13_col2, #T_d0cfa_row13_col3, #T_d0cfa_row13_col4, #T_d0cfa_row14_col0, #T_d0cfa_row14_col1, #T_d0cfa_row14_col2, #T_d0cfa_row14_col3, #T_d0cfa_row14_col4, #T_d0cfa_row15_col0, #T_d0cfa_row15_col1, #T_d0cfa_row15_col2, #T_d0cfa_row15_col3, #T_d0cfa_row15_col4, #T_d0cfa_row16_col0, #T_d0cfa_row16_col1, #T_d0cfa_row16_col2, #T_d0cfa_row16_col3, #T_d0cfa_row16_col4, #T_d0cfa_row17_col0, #T_d0cfa_row17_col1, #T_d0cfa_row17_col2, #T_d0cfa_row17_col3, #T_d0cfa_row17_col4, #T_d0cfa_row18_col0, #T_d0cfa_row18_col1, #T_d0cfa_row18_col2, #T_d0cfa_row18_col3, #T_d0cfa_row18_col4, #T_d0cfa_row19_col0, #T_d0cfa_row19_col1, #T_d0cfa_row19_col2, #T_d0cfa_row19_col3, #T_d0cfa_row19_col4, #T_d0cfa_row20_col0, #T_d0cfa_row20_col1, #T_d0cfa_row20_col2, #T_d0cfa_row20_col3, #T_d0cfa_row20_col4, #T_d0cfa_row21_col0, #T_d0cfa_row21_col1, #T_d0cfa_row21_col2, #T_d0cfa_row21_col3, #T_d0cfa_row21_col4, #T_d0cfa_row22_col0, #T_d0cfa_row22_col1, #T_d0cfa_row22_col2, #T_d0cfa_row22_col3, #T_d0cfa_row22_col4, #T_d0cfa_row23_col0, #T_d0cfa_row23_col1, #T_d0cfa_row23_col2, #T_d0cfa_row23_col3, #T_d0cfa_row23_col4, #T_d0cfa_row24_col0, #T_d0cfa_row24_col1, #T_d0cfa_row24_col2, #T_d0cfa_row24_col3, #T_d0cfa_row24_col4, #T_d0cfa_row25_col0, #T_d0cfa_row25_col1, #T_d0cfa_row25_col2, #T_d0cfa_row25_col3, #T_d0cfa_row25_col4, #T_d0cfa_row26_col0, #T_d0cfa_row26_col1, #T_d0cfa_row26_col2, #T_d0cfa_row26_col3, #T_d0cfa_row26_col4, #T_d0cfa_row27_col0, #T_d0cfa_row27_col1, #T_d0cfa_row27_col2, #T_d0cfa_row27_col3, #T_d0cfa_row27_col4, #T_d0cfa_row28_col0, #T_d0cfa_row28_col1, #T_d0cfa_row28_col2, #T_d0cfa_row28_col3, #T_d0cfa_row28_col4, #T_d0cfa_row29_col0, #T_d0cfa_row29_col1, #T_d0cfa_row29_col2, #T_d0cfa_row29_col3, #T_d0cfa_row29_col4, #T_d0cfa_row30_col0, #T_d0cfa_row30_col1, #T_d0cfa_row30_col2, #T_d0cfa_row30_col3, #T_d0cfa_row30_col4, #T_d0cfa_row31_col0, #T_d0cfa_row31_col1, #T_d0cfa_row31_col2, #T_d0cfa_row31_col3, #T_d0cfa_row31_col4, #T_d0cfa_row32_col0, #T_d0cfa_row32_col1, #T_d0cfa_row32_col2, #T_d0cfa_row32_col3, #T_d0cfa_row32_col4, #T_d0cfa_row33_col0, #T_d0cfa_row33_col1, #T_d0cfa_row33_col2, #T_d0cfa_row33_col3, #T_d0cfa_row33_col4, #T_d0cfa_row34_col0, #T_d0cfa_row34_col1, #T_d0cfa_row34_col2, #T_d0cfa_row34_col3, #T_d0cfa_row34_col4, #T_d0cfa_row35_col0, #T_d0cfa_row35_col1, #T_d0cfa_row35_col2, #T_d0cfa_row35_col3, #T_d0cfa_row35_col4, #T_d0cfa_row36_col0, #T_d0cfa_row36_col1, #T_d0cfa_row36_col2, #T_d0cfa_row36_col3, #T_d0cfa_row36_col4, #T_d0cfa_row37_col0, #T_d0cfa_row37_col1, #T_d0cfa_row37_col2, #T_d0cfa_row37_col3, #T_d0cfa_row37_col4, #T_d0cfa_row38_col0, #T_d0cfa_row38_col1, #T_d0cfa_row38_col ...
